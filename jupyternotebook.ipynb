# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
my_data = pd.read_csv('\\Users\\cofos\\Downloads\\institition.csv',delimiter = ',', header = 0)
my_data.head(3)
# Out:
#       Institution Name  Full Time Enrollment State  \
# 0   Adelphi University                  6562    NY
# 1  Agnes Scott College                   998    GA
# 2       Albion College                  1509    MI
#
#                       Ranking List  Rank  Rank Pct Rank  \
# 0  USN National University Ranking   166          0.280
# 1     USN National College Ranking    58          0.740
# 2     USN National College Ranking   140          0.376
#
#    Undergraduate Admit Rate  Undergraduate Admit Rate Pct Rank  \
# 0                  0.741811                              0.291
# 1                  0.704000                              0.383
# 2                  0.682442                              0.431
#
#    Average Monthly Search Volume  Average Monthly Search Volume Pct Rank  ...  \
# 0                          60500                                   0.695  ...
# 1                          14800                                   0.193  ...
# ...

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438 entries, 0 to 437
# Data columns (total 31 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Institution Name                                    438 non-null    object
#  1   Full Time Enrollment                                438 non-null    int64
#  2   State                                               438 non-null    object
#  3   Ranking List                                        438 non-null    object
#  4   Rank                                                438 non-null    int64
#  5   Rank Pct Rank                                       438 non-null    float64
#  6   Undergraduate Admit Rate                            438 non-null    float64
#  7   Undergraduate Admit Rate Pct Rank                   438 non-null    float64
# ...

# %%
my_data['Percentage of International Students'].value_counts()
# Out:
# 0.0100    82
# 0.0200    58
# 0.0300    47
# 0.0400    37
# 0.0000    30
# 0.0500    23
# 0.0900    18
# 0.1200    16
# 0.1400    15
# 0.0700    15
# 0.0800    14
# 0.1000    14
# 0.0600    12
# 0.1300    10
# 0.1500     6
# 0.1600     6
# 0.1100     6
# 0.1700     5
# 0.1800     4
# 0.2000     4
# 0.1900     3
# 0.2100     2
# 0.3300     1
# 0.0560     1
# 0.2800     1
# 0.0670     1
# 0.0315     1
# 0.0440     1
# 0.2700     1
# 0.3700     1
# 0.2400     1
# 0.2200     1
# 0.0680     1
# Name: Percentage of International Students, dtype: int64

# %%
my_data.shape
# Out:
# (438, 31)

# %%
my_data.describe()
# Out:
#        Full Time Enrollment        Rank  Rank Pct Rank  \
# count            438.000000  438.000000     438.000000
# mean           10553.527397  121.098174       0.506689
# std            11631.953466   78.385230       0.287487
# min              140.000000    1.000000       0.026000
# 25%             1956.250000   57.000000       0.252000
# 50%             5551.000000  114.000000       0.502000
# 75%            15920.500000  179.000000       0.753000
# max            59220.000000  281.000000       1.000000
#
#        Undergraduate Admit Rate  Undergraduate Admit Rate Pct Rank  \
# count                438.000000                         438.000000
# mean                   0.588005                           0.500498
# std                    0.233405                           0.289663
# min                    0.043644                           0.000000
# 25%                    0.440218                           0.250500
# ...

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438 entries, 0 to 437
# Data columns (total 31 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Institution Name                                    438 non-null    object
#  1   Full Time Enrollment                                438 non-null    int64
#  2   State                                               438 non-null    object
#  3   Ranking List                                        438 non-null    object
#  4   Rank                                                438 non-null    int64
#  5   Rank Pct Rank                                       438 non-null    float64
#  6   Undergraduate Admit Rate                            438 non-null    float64
#  7   Undergraduate Admit Rate Pct Rank                   438 non-null    float64
# ...

# %% [markdown]
# m

# %%
value_corr = my_data[['Credential Score', 'Experience Score','Eduation Score','Value\n(C x E x E)', 'Value-to-Cost Ratio']]
value_corr
# Out:
#      Credential Score  Experience Score  Eduation Score  Value\n(C x E x E)  \
# 0               1.266             2.400           1.916            5.821574
# 1               1.316             2.796           0.792            2.914193
# 2               1.065             1.800           1.193            2.286981
# 3               1.485             2.196           1.664            5.426404
# 4               2.368             2.196           1.733            9.011822
# ..                ...               ...             ...                 ...
# 433             0.856             2.400           0.398            0.817651
# 434             1.614             2.598           1.431            6.000429
# 435             2.036             2.400           2.741           13.393622
# 436             2.917             3.000           2.942           25.745442
# 437             1.561             2.796           1.522            6.642854
#
#      Value-to-Cost Ratio
# 0               0.422772
# ...

# %%
corrMatrix = value_corr.corr()
corrMatrix
# Out:
#                      Credential Score  Experience Score  Eduation Score  \
# Credential Score             1.000000          0.470117        0.690523
# Experience Score             0.470117          1.000000        0.372435
# Eduation Score               0.690523          0.372435        1.000000
# Value\n(C x E x E)           0.889974          0.542764        0.864447
# Value-to-Cost Ratio          0.086526          0.186833        0.107426
#
#                      Value\n(C x E x E)  Value-to-Cost Ratio
# Credential Score               0.889974             0.086526
# Experience Score               0.542764             0.186833
# Eduation Score                 0.864447             0.107426
# Value\n(C x E x E)             1.000000             0.104040
# Value-to-Cost Ratio            0.104040             1.000000

# %%
sns.heatmap(corrMatrix, annot=True)

# %%
sns.lineplot(x =my_data['Value\n(C x E x E)'] , y= my_data['Vulnerability Score'])

# %%
matrix_corr = my_data[['Credential Score', 'Experience Score','Eduation Score','Value\n(C x E x E)', 'Value-to-Cost Ratio']]
matrix_corr
# Out:
#      Credential Score  Experience Score  Eduation Score  Value\n(C x E x E)  \
# 0               1.266             2.400           1.916            5.821574
# 1               1.316             2.796           0.792            2.914193
# 2               1.065             1.800           1.193            2.286981
# 3               1.485             2.196           1.664            5.426404
# 4               2.368             2.196           1.733            9.011822
# ..                ...               ...             ...                 ...
# 433             0.856             2.400           0.398            0.817651
# 434             1.614             2.598           1.431            6.000429
# 435             2.036             2.400           2.741           13.393622
# 436             2.917             3.000           2.942           25.745442
# 437             1.561             2.796           1.522            6.642854
#
#      Value-to-Cost Ratio
# 0               0.422772
# ...

# %%
matrix1 = matrix_corr.corr()
matrix1
# Out:
#                      Credential Score  Experience Score  Eduation Score  \
# Credential Score             1.000000          0.470117        0.690523
# Experience Score             0.470117          1.000000        0.372435
# Eduation Score               0.690523          0.372435        1.000000
# Value\n(C x E x E)           0.889974          0.542764        0.864447
# Value-to-Cost Ratio          0.086526          0.186833        0.107426
#
#                      Value\n(C x E x E)  Value-to-Cost Ratio
# Credential Score               0.889974             0.086526
# Experience Score               0.542764             0.186833
# Eduation Score                 0.864447             0.107426
# Value\n(C x E x E)             1.000000             0.104040
# Value-to-Cost Ratio            0.104040             1.000000

# %%
sns.heatmap(matrix1, annot=True)

# %%
matric_data = my_data[['Credential Score', 'Experience Score','Eduation Score','Value\n(C x E x E)', 'Value-to-Cost Ratio','Endowment per Full Time Student',
              'Endowment per Full Time Student Pct Rank','Percentage of International Students', 'Vulnerability Score']]
matric_data
# Out:
#      Credential Score  Experience Score  Eduation Score  Value\n(C x E x E)  \
# 0               1.266             2.400           1.916            5.821574
# 1               1.316             2.796           0.792            2.914193
# 2               1.065             1.800           1.193            2.286981
# 3               1.485             2.196           1.664            5.426404
# 4               2.368             2.196           1.733            9.011822
# ..                ...               ...             ...                 ...
# 433             0.856             2.400           0.398            0.817651
# 434             1.614             2.598           1.431            6.000429
# 435             2.036             2.400           2.741           13.393622
# 436             2.917             3.000           2.942           25.745442
# 437             1.561             2.796           1.522            6.642854
#
# ...

# %%
matrix2 = matric_data.corr()
matrix2
# Out:
#                                           Credential Score  Experience Score  \
# Credential Score                                  1.000000          0.470117
# Experience Score                                  0.470117          1.000000
# Eduation Score                                    0.690523          0.372435
# Value\n(C x E x E)                                0.889974          0.542764
# Value-to-Cost Ratio                               0.086526          0.186833
# Endowment per Full Time Student                   0.503571          0.198122
# Endowment per Full Time Student Pct Rank         -0.566443         -0.096903
# Percentage of International Students              0.584851          0.150000
# Vulnerability Score                               0.116403          0.121365
#
#                                           Eduation Score  Value\n(C x E x E)  \
# Credential Score                                0.690523            0.889974
# ...

# %%
plt.subplots(figsize=(8,5))
sns.heatmap(matrix2, annot=True)

# %%
g = sns.pairplot(my_data, height=3,
                 vars=["Percentage of International Students", "Endowment per Full Time Student"])

# %%
mean_endowment_per_cat = my_data.groupby('Prof G Categorization').mean().reset_index()
mean_endowment_per_cat
# Out:
#   Prof G Categorization  Full Time Enrollment        Rank  Rank Pct Rank  \
# 0                Perish           4656.548387  141.387097       0.432452
# 1              Struggle           3065.658730  136.603175       0.433143
# 2               Survive          20110.833333  110.055556       0.554429
# 3                Thrive          13646.752688   94.763441       0.615892
#
#    Undergraduate Admit Rate  Undergraduate Admit Rate Pct Rank  \
# 0                  0.645884                           0.454140
# 1                  0.694389                           0.374437
# 2                  0.525948                           0.577270
# 3                  0.470069                           0.613634
#
#    Average Monthly Search Volume  Average Monthly Search Volume Pct Rank  \
# 0                   29179.462366                                0.353710
# 1                   23593.492063                                0.304325
# ...

# %%
mean_endowment_per_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 27 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Prof G Categorization                               4 non-null      object
#  1   Full Time Enrollment                                4 non-null      float64
#  2   Rank                                                4 non-null      float64
#  3   Rank Pct Rank                                       4 non-null      float64
#  4   Undergraduate Admit Rate                            4 non-null      float64
#  5   Undergraduate Admit Rate Pct Rank                   4 non-null      float64
#  6   Average Monthly Search Volume                       4 non-null      float64
#  7   Average Monthly Search Volume Pct Rank              4 non-null      float64
# ...

# %%
sns.barplot(x= 'Prof G Categorization', y = 'Endowment per Full Time Student', data = mean_endowment_per_cat)

# %%
sns.barplot(x= 'Prof G Categorization', y = 'Endowment per Full Time Student',hue = 'Percentage of International Students', data = mean_endowment_per_cat)

# %%
sns.barplot(x= 'Prof G Categorization', y = 'Endowment per Full Time Student',hue = 'Vulnerability Score', data = mean_endowment_per_cat)aaaaa

# %%
sns.relplot(x="Vulnerability Score", y="Endowment per Full Time Student", data= my_data);

# %%
sns.relplot(x="Vulnerability Score", y="Percentage of International Students", data= my_data)

# %%
sns.regplot(x="Vulnerability Score", y="Endowment per Full Time Student", data= my_data);

# %%
sns.regplot(x="Vulnerability Score", y="Percentage of International Students", data= my_data);

# %%
sns.barplot(x= 'Prof G Categorization', y = 'Average Monthly Search Volume', data = mean_endowment_per_cat)

# %%
sns.barplot(x= 'Prof G Categorization', y = 'Student Life Score', data = mean_endowment_per_cat)

# %%
sns.barplot(x= 'Prof G Categorization', y = 'Average Undergraduate Tuition and Fees', data = mean_endowment_per_cat)
